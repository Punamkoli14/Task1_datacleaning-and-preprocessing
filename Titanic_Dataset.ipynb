# %%
#Import the nessesary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing the dataset

data=pd.read_csv(r"C:\Users\Admin\Downloads\Titanic-Dataset.csv")

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Display the first few row of dataset

data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Display the last few row of dataset

data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#Shape

data.shape
# Out:
# (891, 12)

# %%
#listing down the columns

data.columns.values
# Out:
# array(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Check the null values

data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Missing values in Age,Cabin and Embarked columns
# more than 70% value are missing in cabin column so will have to drop
# some columns have inappropriate data type

# %%
#drop the cabin column
data.drop(columns=['Cabin'],inplace=True)

# %%
# fill the missing value of the column age
#data['Age'].fillna(data['Age'].mean(),inplace=True)
data['Age'] = data['Age'].fillna(data['Age'].mean())

# %%
# inpute missing value of Embarked column
data['Embarked'].value_counts()
data['Embarked'] = data['Embarked'].fillna('S')

# %%
data['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
data['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
# Changing the datatype of some columns

data['Survived']=data['Survived'].astype("category")
data['Pclass']=data['Pclass'].astype("category")
data['Sex']=data['Sex'].astype("category")
data['Age']=data['Age'].astype("int")
data['Embarked']=data['Embarked'].astype("category")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    category
#  2   Pclass       891 non-null    category
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    category
#  5   Age          891 non-null    int64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     891 non-null    category
# dtypes: category(4), float64(1), int64(4), object(2)
# memory usage: 52.8+ KB

# %%
data.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.544332    0.523008    0.381594   32.204208
# std     257.353842   13.013778    1.102743    0.806057   49.693429
# min       1.000000    0.000000    0.000000    0.000000    0.000000
# 25%     223.500000   22.000000    0.000000    0.000000    7.910400
# 50%     446.000000   29.000000    0.000000    0.000000   14.454200
# 75%     668.500000   35.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# # Univariate Analysis

# %%
# Survived Column

sns.countplot(x='Survived', data=data)  
plt.title("Titanic Survivors Count ")
plt.xlabel("Survived")
plt.ylabel("Count")
plt.show()
depth_percent=round((data['Survived'].value_counts().values[0]/891)*100)
print("Out of 891 .{} people died in the accident".format(depth_percent))
# Out:
# Out of 891 .62 people died in the accident

# %%
#Pclass Column

print(data['Pclass'].value_counts(normalize=True) * 100)

sns.countplot(x='Pclass', data=data)
plt.title("Titanic Pclass Count")
plt.ylabel("Count")
plt.xlabel("Passenger Class")
plt.show()
# Out:
# Pclass
# 3    55.106622
# 1    24.242424
# 2    20.650954
# Name: proportion, dtype: float64

# %%
#Sex Column

print(data['Sex'].value_counts(normalize=True) * 100)

sns.countplot(x='Sex', data=data)
plt.title("Titanic Sex Count")
plt.ylabel("Count")
plt.xlabel("Sex Class")
plt.show()
# Out:
# Sex
# male      64.758698
# female    35.241302
# Name: proportion, dtype: float64

# %%
#SibSp Column

print(data['SibSp'].value_counts(normalize=True) * 100)

sns.countplot(x='SibSp', data=data)
plt.title("Titanic SibSp Count")
plt.ylabel("Count")
plt.xlabel("SibSp Class")
plt.show()
# Out:
# SibSp
# 0    68.237935
# 1    23.456790
# 2     3.142536
# 4     2.020202
# 3     1.795735
# 8     0.785634
# 5     0.561167
# Name: proportion, dtype: float64

# %%
#Parch Column

print(data['Parch'].value_counts(normalize=True) * 100)

sns.countplot(x='Parch', data=data)
plt.title("Titanic Parch Count")
plt.ylabel("Count")
plt.xlabel("Parch Class")
plt.show()
# Out:
# Parch
# 0    76.094276
# 1    13.243547
# 2     8.978676
# 5     0.561167
# 3     0.561167
# 4     0.448934
# 6     0.112233
# Name: proportion, dtype: float64

# %%
# Embarked Column

print(data['Embarked'].value_counts(normalize=True) * 100)

sns.countplot(x='Embarked', data=data)
plt.title("Titanic Embarked Count")
plt.ylabel("Count")
plt.xlabel("Embarked Class")
plt.show()
# Out:
# Embarked
# S    72.502806
# C    18.855219
# Q     8.641975
# Name: proportion, dtype: float64

# %%
sns.displot(data['Age'], kde=True)
print(data['Age'].skew())
print(data['Age'].kurt())
# Out:
# 0.45956263424701577
# 0.9865867453652877

# %%
sns.boxplot(data['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
print("People with age in between age 60 to 70 are ",data[(data['Age']>60) & (data['Age']<70)].shape[0])
print("People with age greater than 70 to 75 are ",data[(data['Age']>=70) & (data['Age']<=75)].shape[0])
print("People with age greater than 75 are ",data[data['Age']>75].shape[0])

print('-' * 50)

print("People with age between 0 to 1  are ",data[data['Age']<1].shape[0])
# Out:
# People with age in between age 60 to 70 are  15
# People with age greater than 70 to 75 are  6
# People with age greater than 75 are  1
# --------------------------------------------------
# People with age between 0 to 1  are  7

# %%
sns.displot(data['Fare'], kde=True)
print(data['Fare'].skew())
print(data['Fare'].kurt())
# Out:
# 4.787316519674893
# 33.39814088089868

# %%
sns.boxplot(data['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
print("People with fare in between $200 and $300",data[(data['Fare']>200) & (data['Fare']<300)].shape[0])
print("People with fare greater than $300",data[data['Fare']>300].shape[0])
# Out:
# People with fare in between $200 and $300 17
# People with fare greater than $300 3

# %%
#Conclusion
#highly skewed data, a lot of people had cheaper tickets
#Outliers are there in data

# %% [markdown]
# # Multivariate Analysis

# %%
#Survived with Pclass

sns.countplot(x='Survived', hue='Pclass', data=data)
pd.crosstab(data['Pclass'],data['Survived']).apply(lambda r: round((r/r.sum())*100,1),axis=1)
# Out:
# Survived     0     1
# Pclass
# 1         37.0  63.0
# 2         52.7  47.3
# 3         75.8  24.2

# %%
# Survived with Sex

sns.countplot(x='Survived', hue='Sex', data=data)
pd.crosstab(data['Sex'],data['Survived']).apply(lambda r: round((r/r.sum())*100,1),axis=1)
# Out:
# Survived     0     1
# Sex
# female    25.8  74.2
# male      81.1  18.9

# %%
#Survived with Embarked

sns.countplot(x='Survived', hue='Embarked', data=data)
pd.crosstab(data['Embarked'],data['Survived']).apply(lambda r: round((r/r.sum())*100,1),axis=1)
# Out:
# Survived     0     1
# Embarked
# C         44.6  55.4
# Q         61.0  39.0
# S         66.1  33.9

# %%
sns.histplot(data[data['Survived']==0]['Age'], kde=True, color='red', label='Not Survived')
sns.histplot(data[data['Survived']==1]['Age'], kde=True, color='green', label='Survived')

# Add legend and title
plt.legend()
plt.title("Age Distribution by Survival")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
sns.histplot(data[data['Survived']==0]['Fare'], kde=True, color='red', label='Not Survived')
sns.histplot(data[data['Survived']==1]['Fare'], kde=True, color='green', label='Survived')

# Add legend and title
plt.legend()
plt.title("Fare Distribution by Survival")
plt.xlabel("Fare")
plt.ylabel("Count")
plt.show()

# %%
sns.pairplot(data)

# %%
numeric_data = data.select_dtypes(include='number')

# Plot heatmap
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap (Numeric Features Only)")
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
#New column -> Family = SibSp + Parch

# %%
data['family_size']=data['SibSp'] + data['Parch']

# %%
data.sample(5)
# Out:
#      PassengerId Survived Pclass  \
# 132          133        0      3
# 391          392        1      3
# 622          623        1      3
# 479          480        1      3
# 682          683        0      3
#
#                                                Name     Sex  Age  SibSp  \
# 132  Robins, Mrs. Alexander A (Grace Charity Laury)  female   47      1
# 391                          Jansson, Mr. Carl Olof    male   21      0
# 622                                Nakid, Mr. Sahid    male   20      1
# 479                        Hirvonen, Miss. Hildur E  female    2      0
# 682                     Olsvigen, Mr. Thor Anderson    male   20      0
#
#      Parch     Ticket     Fare Embarked  family_size
# 132      0  A/5. 3337  14.5000        S            1
# 391      0     350034   7.7958        S            0
# 622      1       2653  15.7417        C            2
# 479      1    3101298  12.2875        S            1
# 682      0       6563   9.2250        S            0

# %%
# we will engineer a new feature  by the name of famity type
# Step 1: Define the function
def family_type(size):
    if size == 1:
        return 'Alone'
    elif size <= 4:
        return 'medium'
    else:
        return 'Large'

# Step 2: Apply the function to the 'family_size' column
data['family_type'] = data['family_size'].apply(family_type)

# %%
data.sample(5)
# Out:
#      PassengerId Survived Pclass                                       Name  \
# 270          271        0      1                      Cairns, Mr. Alexander
# 306          307        1      1                    Fleming, Miss. Margaret
# 347          348        1      3  Davison, Mrs. Thomas Henry (Mary E Finck)
# 109          110        1      3                        Moran, Miss. Bertha
# 120          121        0      2                Hickman, Mr. Stanley George
#
#         Sex  Age  SibSp  Parch        Ticket      Fare Embarked  family_size  \
# 270    male   29      0      0        113798   31.0000        S            0
# 306  female   29      0      0         17421  110.8833        C            0
# 347  female   29      1      0        386525   16.1000        S            1
# 109  female   29      1      0        371110   24.1500        Q            1
# 120    male   21      2      0  S.O.C. 14879   73.5000        S            2
#
#     family_type
# 270      medium
# ...

# %%
#droping the SibSp ,Parch and family_size

# %%
data.drop(columns=['SibSp' ,'Parch' , 'family_size'],inplace=True)

# %%
data.head(5)
# Out:
#    PassengerId Survived Pclass  \
# 0            1        0      3
# 1            2        1      1
# 2            3        1      3
# 3            4        1      1
# 4            5        0      3
#
#                                                 Name     Sex  Age  \
# 0                            Braund, Mr. Owen Harris    male   22
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 2                             Heikkinen, Miss. Laina  female   26
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 4                           Allen, Mr. William Henry    male   35
#
#              Ticket     Fare Embarked family_type
# 0         A/5 21171   7.2500        S       Alone
# 1          PC 17599  71.2833        C       Alone
# 2  STON/O2. 3101282   7.9250        S      medium
# 3            113803  53.1000        S       Alone
# 4            373450   8.0500        S      medium

# %%
pd.crosstab(data['family_type'],data['Survived']).apply(lambda r: round((r/r.sum())*100,1),axis=1)
# Out:
# Survived        0     1
# family_type
# Alone        44.7  55.3
# Large        85.1  14.9
# medium       64.0  36.0

# %% [markdown]
# # Detecting Outliers

# %%
#handing outlier in age

# %%
data=data[data['Age']<(data['Age'].mean() +3 * data['Age'].std())]
data.shape
# Out:
# (884, 10)

# %%
#handing outliers from Fare column

Q1=np.percentile(data['Fare'],25)
Q3=np.percentile(data['Fare'],75)

outlier_low=Q1 - 1.5 * (Q3 -Q1)
outlier_high=Q3 + 1.5 * (Q3 -Q1)

data=data[(data['Fare']> outlier_low) & (data['Fare']<outlier_high)]

# %%
# One hot encoding

data.sample(5)

#columns to be transformed are Pclass, Sex , Embarked ,family_type

#df_encoded=pd.get_dummies(data=data, columns=['Pclass', 'Sex' , 'Embarked' ,'family_type'],drop_first=True)
df_encoded = pd.get_dummies(data=data, columns=['Pclass', 'Sex', 'Embarked', 'family_type'], drop_first=True, dtype=int)
df_encoded.head(10)
# Out:
#     PassengerId Survived                                               Name  \
# 0             1        0                            Braund, Mr. Owen Harris
# 2             3        1                             Heikkinen, Miss. Laina
# 3             4        1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4             5        0                           Allen, Mr. William Henry
# 5             6        0                                   Moran, Mr. James
# 6             7        0                            McCarthy, Mr. Timothy J
# 7             8        0                     Palsson, Master. Gosta Leonard
# 8             9        1  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9            10        1                Nasser, Mrs. Nicholas (Adele Achem)
# 10           11        1                    Sandstrom, Miss. Marguerite Rut
#
#     Age            Ticket     Fare  Pclass_2  Pclass_3  Sex_male  Embarked_Q  \
# ...

# %%
#plt.figure(figsize=(15,6))
#sns.heatmap(df_encoded.corr(),cmap='summer')
numeric_data =df_encoded .select_dtypes(include='number')

# Plot heatmap
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap (Numeric Features Only)")
plt.show()
